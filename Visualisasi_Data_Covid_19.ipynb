# %% [markdown]
# <a href="https://colab.research.google.com/github/FataPutra/DataMining/blob/main/Visualisasi_Data_Covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
data = pd.read_csv("Data Covid19.csv")
data.head()

# %%
data.info()

# %%
data['Last Update'].unique()
# Out:
# array(['1/22/2020 17:00', '1/23/20 17:00', '1/24/20 17:00', ...,
#        '26/02/2021 05.22', '27/02/2021 05.22', '28/02/2021 05.22'],
#       dtype=object)

# %%
latest_date = '28/02/2021 05.22'
data[data['Last Update']==latest_date]

# %%
unique_countries = data[data.Confirmed>0]['Country/Region'].unique()
unique_countries.sort()
unique_countries

# %%
country_confirmed_case = []
for i in unique_countries:
  country_confirmed_case.append(data[data.Confirmed>0][data['Country/Region']==i][data['Last Update']==latest_date].Confirmed.sum())
# Out:
# <ipython-input-33-1d4d890109d8>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   country_confirmed_case.append(data[data.Confirmed>0][data['Country/Region']==i][data['Last Update']==latest_date].Confirmed.sum())

# %%
print(set(zip(unique_countries, country_confirmed_case)))
# Out:
# {('Mongolia', 2907), ('Lithuania', 197343), ('Sierra Leone', 3887), ('Nepal', 274065), ('Taiwan', 954), ('Guam', 0), ('Uzbekistan', 79836), ('Laos', 45), ('Grenada', 148), ('Sao Tome and Principe', 1786), ('Netherlands', 1098875), ('Guinea', 15894), ('Denmark', 211420), ('Antigua and Barbuda', 726), ('Burma', 141890), ('Palestine', 0), ('Holy See', 27), ('Guinea-Bissau', 3247), ('Lesotho', 10491), ('Liechtenstein', 2566), ('Burundi', 2181), ('Slovakia', 306268), ('Brazil', 10517232), ('Yemen', 2269), ('Paraguay', 158537), ('Maldives', 19597), ('Bulgaria', 246706), ('Vatican City', 0), ('Romania', 799164), ('Norway', 70826), ('Belgium', 769414), ('Madagascar', 19831), ('Mayotte', 0), ('Sri Lanka', 82890), ('Seychelles', 2592), ('Syria', 15533), ('Equatorial Guinea', 6005), ('Trinidad and Tobago', 7705), ('Morocco', 483410), ('Moldova', 184856), ('Belarus', 285959), ('Angola', 20782), ('Cambodia', 805), ('Ecuador', 284347), ('Djibouti', 6065), ('Albania', 106215), ('Bosnia and Herzegovina', 130979), ('Dominica', 142), ('Singapore', 59925), ('Ivory Coast', 32631), ('Armenia', 171793), ('Spain', 3188553), ('Niger', 4740), ('Panama', 340445), ('Gibraltar', 0), ('Jamaica', 22817), ('Malawi', 31798), ('Reunion', 0), ('Cameroon', 35714), ('Luxembourg', 55110), ('Cuba', 49161), ('Israel', 773335), ('Saint Kitts and Nevis', 41), ('Costa Rica', 204341), ('Congo (Kinshasa)', 25792), ('South Korea', 89676), ('East Timor', 0), ('Kenya', 105648), ('Saint Lucia', 3356), ('South Sudan', 7771), ('Canada', 869347), ('Diamond Princess', 712), ('Pakistan', 579973), ('Algeria', 112960), ('The Gambia', 0), ('Greenland', 0), ('Montenegro', 75332), ('Kazakhstan', 262093), ('Philippines', 574247), ('Greece', 189831), ('Finland', 57052), ('Turkey', 2693164), ('Austria', 457317), ('Nicaragua', 6445), ('Japan', 431093), ('Chad', 3973), ('Republic of Ireland', 0), ('Mozambique', 58772), ('Venezuela', 138739), ('Hong Kong', 10983), ('UK', 4182772), ('Mexico', 2084128), ('Brunei', 186), ('Guyana', 8550), ('Portugal', 803844), ('South Africa', 1512225), ('Lebanon', 372792), ('Switzerland', 554932), ('Libya', 132458), ('Benin', 5434), ('Solomon Islands', 18), ('Estonia', 64399), ('Oman', 140588), ('Marshall Islands', 4), ('Serbia', 456450), ('Iceland', 6049), ('Timor-Leste', 111), ('Uruguay', 57362), ('Poland', 1696885), ('Sweden', 657309), ('Malta', 22219), ('Afghanistan', 55707), ('Ukraine', 1389570), ('Germany', 2444177), ('Cabo Verde', 15324), ('El Salvador', 59866), ('St. Martin', 0), ('Hungary', 424130), ('Barbados', 3038), ('Liberia', 2010), ('Puerto Rico', 0), ('Monaco', 1953), ('Bangladesh', 545831), ('French Guiana', 0), ('Croatia', 242617), ('Samoa', 3), ('Somalia', 6991), ('occupied Palestinian territory', 0), ('Togo', 6851), ('Slovenia', 189627), ('Dominican Republic', 239009), ('Micronesia', 1), ('Tajikistan', 13308), ('Zimbabwe', 36058), ('Mauritius', 610), ('Martinique', 0), ('Ghana', 82586), ('Nigeria', 155417), ('North Macedonia', 102482), ('Peru', 1323863), ('West Bank and Gaza', 181909), ('Haiti', 12430), ('Bahrain', 121778), ("('St. Martin',)", 0), ('Guernsey', 0), ('Macau', 48), ('Czech Republic', 1227595), ('Vietnam', 2432), ('Burkina Faso', 11982), ('Papua New Guinea', 1275), ('Uganda', 40335), ('Rwanda', 18790), ('Senegal', 34255), ('Zambia', 78202), ('Latvia', 85810), ('France', 3747263), ('Cape Verde', 0), ('Colombia', 2248135), ('Thailand', 25951), ('United Arab Emirates', 388594), ('Comoros', 3571), ('Bahamas', 8519), ('Kyrgyzstan', 86185), ('Central African Republic', 5004), ('Saint Barthelemy', 0), ('Tunisia', 232615), ('The Bahamas', 0), ('Gambia, The', 0), ('Kuwait', 189890), ('Egypt', 181829), ('Mauritania', 17196), ('Qatar', 163197), ('Kosovo', 68451), ('Sudan', 30316), ('MS Zaandam', 9), (' Azerbaijan', 0), ('Iran', 1623159), ('Andorra', 10849), ('Honduras', 169754), ('Tanzania', 509), ('Bahamas, The', 0), ('Congo (Brazzaville)', 8820), ('Curacao', 0), ('Fiji', 59), ('Guatemala', 174335), ('Georgia', 270510), ('Ireland', 218 ...

# %%
unique_provinces = data['Province/State'][data.Confirmed>1].unique()
unique_provinces

# %%
province_confirmed_case = []
for i in unique_provinces:
  province_confirmed_case.append(data[data.Confirmed>0][data['Province/State']==i][data['Last Update']==latest_date].Confirmed.sum())
# Out:
# <ipython-input-20-d611d3719f0b>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   province_confirmed_case.append(data[data.Confirmed>0][data['Province/State']==i][data['Last Update']==latest_date].Confirmed.sum())

# %%
print(set(zip(unique_provinces, province_confirmed_case)))
# Out:
# {('Tatarstan Republic', 17923), ('Faroe Islands', 658), ('Saint Barthelemy', 573), ('Portland, OR', 0), ('Xinjiang', 980), ('Michoacan', 43112), ('Omsk Oblast', 40831), ('Molise', 10547), ('Lviv Oblast', 78519), ('Saratoga County, NY', 0), ('Bonaire, Sint Eustatius and Saba', 196), ('Kochi', 884), ('Sachsen', 194177), ('Pais Vasco', 150674), ('Kagawa', 749), ('Rostov Oblast', 72745), ('Iwate', 554), ('Missouri', 494805), ('Mie', 2520), ('Greenland', 30), ('England', 3653272), ('Santa Clara County, CA', 0), ('Kirovohrad Oblast', 10598), ('Tasmania', 234), ('Punjab', 352946), ('Puducherry', 39717), ('Berlin', 129257), ('Fench Guiana', 0), ('Poltava Oblast', 46067), ('Tyva Republic', 15643), ('Rheinland-Pfalz', 102006), ('Khakassia Republic', 21272), ('Mizoram', 4423), ('Texas', 2649363), ('Diamond Princess cruise ship', 49), ('Lee County, FL', 0), ('Broward County, FL', 0), ('Yamanashi', 941), ('Denmark', 0), ('Tabasco', 57324), ('Lazio', 232887), ('Maharashtra', 2146777), ('Tripura', 33417), ('Nizhny Novgorod Oblast', 96182), ('Cundinamarca', 105433), ('Schleswig-Holstein', 42445), ('Alberta', 133203), ('Kumamoto', 3441), ('Tokushima', 449), ('Hidalgo', 34477), ('Distrito Federal', 295615), ('OHiggins', 30127), ('Los Rios', 19182), ('Jamtland Harjedalen', 6822), ('Los Angeles, CA', 0), ('Aruba', 7876), ('Michigan', 645550), ('Dadra and Nagar Haveli and Daman and Diu', 3406), ('Irkutsk Oblast', 55433), ('West Virginia', 131580), ('British Virgin Islands', 153), ('Navarra', 51244), ('Rio de Janeiro', 582164), ('Aichi', 25858), ('Northern Mariana Islands', 143), ('Araucania', 39823), ('Western Australia', 913), ('Chandigarh', 21719), ('Pennsylvania', 931531), ('Shiga', 2462), ('Turks and Caicos Islands', 2099), ('Oita', 1291), ('Goa', 54932), ('Acre', 57337), ('UK', 0), ('Altai Republic', 16181), ('Zaporizhia Oblast', 69504), ('Kalmar', 11315), ('Norte de Santander', 50712), ('St Martin', 1544), ('Galicia', 111461), ('Unassigned Location (From Diamond Princess)', 0), ('Lambayeque', 38054), ('Santander', 90875), ('Caqueta', 17018), ('Chukotka Autonomous Okrug', 690), ('Namur', 40351), ('Guizhou', 147), ('Guangdong', 2206), ('Ohio', 966154), ('Yamagata', 543), ('Virgin Islands', 2646), ('Fulton County, GA', 0), ('Ancash', 42507), ('Westchester County, NY', 0), ('Moquegua', 19873), ('Cayman Islands', 444), ('Capital District', 657198), ('Pskov Oblast', 31806), ('Yamalo-Nenets Autonomous Okrug', 37071), ('Nagaland', 12199), ('Chelyabinsk Oblast', 50633), ('Saitama', 29292), ('Noord-Holland', 185330), ('Zuid-Holland', 255335), ('Saint Petersburg', 366238), ('Sardegna', 41114), ('Ivano-Frankivsk Oblast', 63699), ('Fukuoka', 18049), ('San Martin', 29634), ('Niigata', 1077), ('Tver Oblast', 33584), ('Illinois', 1185367), ('Cauca', 27343), ('Quintana Roo', 20189), ('Udmurt Republic', 28130), ('Campeche', 8474), ('Krasnoyarsk Krai', 62411), ('Jackson County, OR ', 0), ('Orange County, CA', 0), ('Denver County, CO', 0), ('Varmland', 9115), ('Oaxaca', 40403), ('Ulyanovsk Oblast', 47590), ('Jilin', 573), ('Ica', 40802), ('Magadan Oblast', 8133), ('Washoe County, NV', 0), ('Georgia', 1004187), ('Andhra Pradesh', 889799), ('Emilia-Romagna', 258007), ('Alagoas', 131066), ('Umbria', 44471), ('Aysen', 3062), ('Jiangsu', 704), ('Huancavelica', 9565), ('Ladakh', 9818), ('Gavleborg', 21256), ('Aguascalientes', 23081), ('Kiev', 137656), ('Jiangxi', 935), ('Tyumen Oblast', 31223), ('Assam', 217527), ('Loreto', 31457), ('France', 0), ('Jalisco', 77964), ('Veracruz', 55081), ('Saint Pierre and Miquelon', 24), ('From Diamond Princess', 0), ('Mexico', 216698), ('Arequipa', 60207), ('Halland', 23637), ('Karnataka', 950730), ('Norfolk County, MA', 0), ('Utrecht', 86200), ('Gunma', 4492), ('Amur Oblast', 20970), ('Henan', 1304), ('Balochistan', 19045), ('Hainan', 171), ('Khyber Pakhtunkhwa', 72162), ('Maine', 44493), ('Wisconsin', 616886), ('Sverdlovsk Oblast', 77513), ('Falkland Islands (Islas Malvinas)', 0), ('Tokyo', 110577), ('Oregon', 155315), ('New York  ...

# %%
nan_indices = []
for i in range(len(unique_provinces)):
  if type(unique_provinces[i])==float:
    nan_indices.append(i)

# %%
unique_provinces = list(unique_provinces)
province_confirmed_case = list(province_confirmed_case)

# %%
for i in nan_indices:
  unique_provinces.pop(i)
  province_confirmed_case.pop(i)

unique_provinces

# %%
plt.barh(unique_countries, country_confirmed_case)
plt.show()

# %%
plt.figure(figsize=(50,40))
plt.barh(unique_provinces, province_confirmed_case)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(country_confirmed_case)
plt.legend(unique_countries, loc ='best')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(20,20))
plt.pie(province_confirmed_case)
plt.legend(unique_provinces, loc='best')
plt.show()
